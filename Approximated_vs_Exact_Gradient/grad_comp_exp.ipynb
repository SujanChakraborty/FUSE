# %%
# %run fuse_stability_analysis_updated.py
# Out:
# ...
#   Dataset : cora
# ...
#
#   Phase 1 — end-to-end timing (3 runs each) ...
#     [timing run 1/3]  exact=27.590s  approx=14.960s  ratio=1.844x
#     [timing run 2/3]  exact=27.605s  approx=14.940s  ratio=1.848x
#     [timing run 3/3]  exact=27.878s  approx=15.430s  ratio=1.807x
#
#   Timing result:
#     exact  : 27.691s +/- 0.133s
#     approx : 15.110s +/- 0.226s
#     speedup (approx is faster by): 1.833x
#
#   Phase 2 — gradient geometry diagnostics (200 iterations) ...
#     ||g_e|| : 13.2433 +/- 1.6958  (instability ratio vs approx: 1.000x)
#     ||g_a|| : 13.2433 +/- 1.6958
#     cos     : 0.9957 +/- 0.0015  (min=0.9933)
#     ratio   : 1.0000 +/- 0.0000
#
#   Phase 3 — GNN evaluation on final embeddings ...
#     [GNN] gcn ... exact=0.8202  approx=0.8202
#     [GNN] gat ... exact=0.8350  approx=0.8350
#     [GNN] graphsage ... exact=0.8436  approx=0.8436
#
#   Quality (final embedding accuracy, exact / approx):
#     gcn           exact=0.8202  approx=0.8202
# ...
