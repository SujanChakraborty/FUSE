# %%
from benchmarking_utils_other_baselines import run_benchmark

results = run_benchmark(
    datasets=['cora', 'citeseer', 'pubmed', 'wikics', 'photo'],
    seeds=[42, 46, 123, 999, 2025],
    mask_fracs=[0.7, 0.3],
    emb_dim=150,
    embedding_methods=['coles', 'cca_ssg'],
    classifiers=['gcn', 'gat', 'graphsage'],
    device='cpu',
    vgae_epochs=200,
    dgi_epochs=200,
    fuse_iterations=200,
    save_dir='./benchmark_outputs/other_baselines',
    masks_root='./masks',
    verbose=True
)
# Out:
# Using custom mask: ./masks\Cora\70_30\Cora_70_30_masked_indices_seed42.npy
# [cora][seed=42][mf=0.7] Masked=812, Unmasked=1896
# [cora][seed=42][mask_frac=0.7] Running coles …
# [COLES] Total runtime: 1.00 seconds.
# Embedding: coles, Classifier: gcn
# Accuracy: 0.7131
# Embedding generation time: 1.00s
# Classifier runtime: 5.12s
# --------------------------------------------------
# Embedding: coles, Classifier: gat
# Accuracy: 0.7635
# Embedding generation time: 1.00s
# Classifier runtime: 18.71s
# --------------------------------------------------
# Embedding: coles, Classifier: graphsage
# Accuracy: 0.7451
# Embedding generation time: 1.00s
# Classifier runtime: 11.88s
# --------------------------------------------------
# [cora][seed=42][mask_frac=0.7] Running cca_ssg …
# [CCA-SSG] Training | epochs=100
#   Epoch 020/100 | Loss = -96.5345
#   Epoch 040/100 | Loss = -104.8922
#   Epoch 060/100 | Loss = -107.2853
#   Epoch 080/100 | Loss = -108.6643
# ...

# %%
from benchmarking_utils_other_baselines import run_benchmark

results = run_benchmark(
    datasets=['cora', 'citeseer', 'pubmed', 'wikics', 'photo'],
    seeds=[42, 46, 123, 999, 2025],
    mask_fracs=[0.7, 0.3],
    emb_dim=150,
    embedding_methods=['mvgrl'],
    classifiers=['gcn', 'gat', 'graphsage'],
    device='cpu',
    vgae_epochs=200,
    dgi_epochs=200,
    fuse_iterations=200,
    save_dir='./benchmark_outputs/other_baselines',
    masks_root='./masks',
    verbose=True
)
# Out:
# Using custom mask: ./masks\Cora\70_30\Cora_70_30_masked_indices_seed42.npy
# [cora][seed=42][mf=0.7] Masked=812, Unmasked=1896
# [cora][seed=42][mask_frac=0.7] Running mvgrl …
# [MVGRL] Epoch 200/1000 | Loss 0.1603
# [MVGRL] Epoch 400/1000 | Loss 0.0868
# [MVGRL] Epoch 600/1000 | Loss 0.0840
# [MVGRL] Epoch 800/1000 | Loss 0.0500
# [MVGRL] Epoch 1000/1000 | Loss 0.0434
# [MVGRL] Total runtime: 518.57s
# Embedding: mvgrl, Classifier: gcn
# Accuracy: 0.3325
# Embedding generation time: 518.59s
# Classifier runtime: 5.25s
# --------------------------------------------------
# Embedding: mvgrl, Classifier: gat
# Accuracy: 0.6576
# Embedding generation time: 518.59s
# Classifier runtime: 19.85s
# --------------------------------------------------
# Embedding: mvgrl, Classifier: graphsage
# Accuracy: 0.6096
# Embedding generation time: 518.59s
# Classifier runtime: 12.85s
# --------------------------------------------------
# ...
