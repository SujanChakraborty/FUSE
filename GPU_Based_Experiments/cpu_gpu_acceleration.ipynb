# %%
import torch

# Verify GPU is ready
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")
print(f"GPU: {torch.cuda.get_device_name(0) if device == 'cuda' else 'None'}")
print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB" if device == 'cuda' else "")
# Out:
# Using device: cuda
# GPU: NVIDIA T400 4GB
# VRAM: 4.3 GB

# %%
from benchmarking_utils_gpu_accelerated_variant import run_benchmark

results = run_benchmark(
    datasets=['cora', 'citeseer', 'pubmed', 'wikics', 'photo'],
    seeds=[42, 46, 123, 999, 2025],
    mask_fracs=[0.7, 0.3],
    emb_dim=150,
    embedding_methods=['fuse', 'random', 'given', 'deepwalk', 'node2vec', 'vgae', 'dgi'],
    classifiers=['gcn', 'gat', 'graphsage'],
    device=device,   # <-- picks cuda automatically if available
    vgae_epochs=200,
    dgi_epochs=200,
    fuse_iterations=200,
    save_dir='./benchmark_outputs/gpu_results',
    masks_root='./masks',
    verbose=True
)
# Out:
# Using custom mask: ./masks\Cora\70_30\Cora_70_30_masked_indices_seed42.npy
# [cora][seed=42][mf=0.7] Masked=812, Unmasked=1896
# [cora][seed=42][mask_frac=0.7] Running fuse …
# Embedding: fuse, Classifier: gcn
# Accuracy: 0.8103
# Embedding generation time: 4.03s
# Classifier runtime: 6.39s
# --------------------------------------------------
# Embedding: fuse, Classifier: gat
# Accuracy: 0.8190
# Embedding generation time: 4.03s
# Classifier runtime: 25.62s
# --------------------------------------------------
# Embedding: fuse, Classifier: graphsage
# Accuracy: 0.8103
# Embedding generation time: 4.03s
# Classifier runtime: 15.15s
# --------------------------------------------------
# [cora][seed=42][mask_frac=0.7] Running random …
# Embedding: random, Classifier: gcn
# Accuracy: 0.4754
# Embedding generation time: 0.01s
# Classifier runtime: 6.40s
# --------------------------------------------------
# Embedding: random, Classifier: gat
# Accuracy: 0.5948
# ...
